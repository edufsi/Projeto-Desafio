# %% [markdown]
# <a href="https://colab.research.google.com/github/edufsi/Projeto-Desafio/blob/Eduardo/Importa%C3%A7%C3%A3oDadosCommodities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Deve haver uma forma mais fácil de fazer isso. Infelizmente, estava perdendo muito tempo tentando encontrar uma, então vai ser na ignorância:
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1988.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1989.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1990.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1991.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1992.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1993.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1994.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1995.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1996.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1997.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1998.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1999.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2000.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2001.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2002.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2003.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2004.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2005.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2006.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2007.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2008.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2009.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2010.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2011.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2012.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2013.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2014.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2015.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2016.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2017.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2018.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2019.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2020.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2021.zip
# !wget https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2022.zip
# Out:
# --2024-04-23 00:01:10--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1988.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1988.zip [following]
# --2024-04-23 00:01:10--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1988.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 137975 (135K) [application/zip]
# Saving to: ‘Commoditites1988.zip.1’
#
# Commoditites1988.zi 100%[===================>] 134.74K  --.-KB/s    in 0.01s
#
# 2024-04-23 00:01:10 (10.5 MB/s) - ‘Commoditites1988.zip.1’ saved [137975/137975]
#
# --2024-04-23 00:01:10--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1989.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1989.zip [following]
# --2024-04-23 00:01:11--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1989.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 267605 (261K) [application/zip]
# Saving to: ‘Commoditites1989.zip.1’
#
# Commoditites1989.zi 100%[===================>] 261.33K  --.-KB/s    in 0.02s
#
# 2024-04-23 00:01:11 (13.3 MB/s) - ‘Commoditites1989.zip.1’ saved [267605/267605]
#
# --2024-04-23 00:01:11--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1990.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1990.zip [following]
# --2024-04-23 00:01:11--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1990.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 302579 (295K) [application/zip]
# Saving to: ‘Commoditites1990.zip.1’
#
# Commoditites1990.zi 100%[===================>] 295.49K  --.-KB/s    in 0.02s
#
# 2024-04-23 00:01:11 (15.5 MB/s) - ‘Commoditites1990.zip.1’ saved [302579/302579]
#
# --2024-04-23 00:01:11--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1991.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1991.zip [following]
# --2024-04-23 00:01:12--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1991.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386605 (378K) [application/zip]
# Saving to: ‘Commoditites1991.zip.1’
#
# Commoditites1991.zi 100%[===================>] 377.54K  --.-KB/s    in 0.02s
#
# 2024-04-23 00:01:12 (19.0 MB/s) - ‘Commoditites1991.zip.1’ saved [386605/386605]
#
# --2024-04-23 00:01:12--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1992.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1992.zip [following]
# --2024-04-23 00:01:12--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1992.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 526623 (514K) [application/zip]
# Saving to: ‘Commoditites1992.zip.1’
#
# Commoditites1992.zi 100%[===================>] 514.28K  --.-KB/s    in 0.03s
#
# 2024-04-23 00:01:13 (16.5 MB/s) - ‘Commoditites1992.zip.1’ saved [526623/526623]
#
# --2024-04-23 00:01:13--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1993.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1993.zip [following]
# --2024-04-23 00:01:13--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1993.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 639473 (624K) [application/zip]
# Saving to: ‘Commoditites1993.zip.1’
#
# Commoditites1993.zi 100%[===================>] 624.49K  --.-KB/s    in 0.03s
#
# 2024-04-23 00:01:13 (21.6 MB/s) - ‘Commoditites1993.zip.1’ saved [639473/639473]
#
# --2024-04-23 00:01:13--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1994.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1994.zip [following]
# --2024-04-23 00:01:14--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1994.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 845100 (825K) [application/zip]
# Saving to: ‘Commoditites1994.zip.1’
#
# Commoditites1994.zi 100%[===================>] 825.29K  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:14 (21.8 MB/s) - ‘Commoditites1994.zip.1’ saved [845100/845100]
#
# --2024-04-23 00:01:14--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1995.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1995.zip [following]
# --2024-04-23 00:01:15--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1995.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 936535 (915K) [application/zip]
# Saving to: ‘Commoditites1995.zip.1’
#
# Commoditites1995.zi 100%[===================>] 914.58K  --.-KB/s    in 0.03s
#
# 2024-04-23 00:01:15 (34.4 MB/s) - ‘Commoditites1995.zip.1’ saved [936535/936535]
#
# --2024-04-23 00:01:15--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1996.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1996.zip [following]
# --2024-04-23 00:01:15--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1996.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1017734 (994K) [application/zip]
# Saving to: ‘Commoditites1996.zip.1’
#
# Commoditites1996.zi 100%[===================>] 993.88K  --.-KB/s    in 0.03s
#
# 2024-04-23 00:01:15 (28.9 MB/s) - ‘Commoditites1996.zip.1’ saved [1017734/1017734]
#
# --2024-04-23 00:01:15--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1997.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1997.zip [following]
# --2024-04-23 00:01:16--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1997.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1059150 (1.0M) [application/zip]
# Saving to: ‘Commoditites1997.zip.1’
#
# Commoditites1997.zi 100%[===================>]   1.01M  --.-KB/s    in 0.03s
#
# 2024-04-23 00:01:16 (29.7 MB/s) - ‘Commoditites1997.zip.1’ saved [1059150/1059150]
#
# --2024-04-23 00:01:16--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1998.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1998.zip [following]
# --2024-04-23 00:01:17--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1998.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1113973 (1.1M) [application/zip]
# Saving to: ‘Commoditites1998.zip.1’
#
# Commoditites1998.zi 100%[===================>]   1.06M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:17 (29.5 MB/s) - ‘Commoditites1998.zip.1’ saved [1113973/1113973]
#
# --2024-04-23 00:01:17--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites1999.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1999.zip [following]
# --2024-04-23 00:01:17--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites1999.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1164700 (1.1M) [application/zip]
# Saving to: ‘Commoditites1999.zip.1’
#
# Commoditites1999.zi 100%[===================>]   1.11M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:18 (29.6 MB/s) - ‘Commoditites1999.zip.1’ saved [1164700/1164700]
#
# --2024-04-23 00:01:18--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2000.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2000.zip [following]
# --2024-04-23 00:01:18--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2000.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1313902 (1.3M) [application/zip]
# Saving to: ‘Commoditites2000.zip.1’
#
# Commoditites2000.zi 100%[===================>]   1.25M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:18 (32.9 MB/s) - ‘Commoditites2000.zip.1’ saved [1313902/1313902]
#
# --2024-04-23 00:01:18--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2001.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2001.zip [following]
# --2024-04-23 00:01:19--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2001.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1323754 (1.3M) [application/zip]
# Saving to: ‘Commoditites2001.zip.1’
#
# Commoditites2001.zi 100%[===================>]   1.26M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:19 (32.4 MB/s) - ‘Commoditites2001.zip.1’ saved [1323754/1323754]
#
# --2024-04-23 00:01:19--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2002.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2002.zip [following]
# --2024-04-23 00:01:20--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2002.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1348723 (1.3M) [application/zip]
# Saving to: ‘Commoditites2002.zip.1’
#
# Commoditites2002.zi 100%[===================>]   1.29M  --.-KB/s    in 0.03s
#
# 2024-04-23 00:01:20 (37.1 MB/s) - ‘Commoditites2002.zip.1’ saved [1348723/1348723]
#
# --2024-04-23 00:01:20--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2003.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2003.zip [following]
# --2024-04-23 00:01:20--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2003.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1385281 (1.3M) [application/zip]
# Saving to: ‘Commoditites2003.zip.1’
#
# Commoditites2003.zi 100%[===================>]   1.32M  --.-KB/s    in 0.03s
#
# 2024-04-23 00:01:20 (38.0 MB/s) - ‘Commoditites2003.zip.1’ saved [1385281/1385281]
#
# --2024-04-23 00:01:21--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2004.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2004.zip [following]
# --2024-04-23 00:01:21--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2004.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1422461 (1.4M) [application/zip]
# Saving to: ‘Commoditites2004.zip.1’
#
# Commoditites2004.zi 100%[===================>]   1.36M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:21 (34.5 MB/s) - ‘Commoditites2004.zip.1’ saved [1422461/1422461]
#
# --2024-04-23 00:01:21--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2005.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2005.zip [following]
# --2024-04-23 00:01:22--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2005.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1436484 (1.4M) [application/zip]
# Saving to: ‘Commoditites2005.zip.1’
#
# Commoditites2005.zi 100%[===================>]   1.37M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:22 (37.0 MB/s) - ‘Commoditites2005.zip.1’ saved [1436484/1436484]
#
# --2024-04-23 00:01:22--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2006.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2006.zip [following]
# --2024-04-23 00:01:22--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2006.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1465086 (1.4M) [application/zip]
# Saving to: ‘Commoditites2006.zip.1’
#
# Commoditites2006.zi 100%[===================>]   1.40M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:23 (39.6 MB/s) - ‘Commoditites2006.zip.1’ saved [1465086/1465086]
#
# --2024-04-23 00:01:23--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2007.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2007.zip [following]
# --2024-04-23 00:01:23--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2007.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1482831 (1.4M) [application/zip]
# Saving to: ‘Commoditites2007.zip.1’
#
# Commoditites2007.zi 100%[===================>]   1.41M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:23 (39.7 MB/s) - ‘Commoditites2007.zip.1’ saved [1482831/1482831]
#
# --2024-04-23 00:01:23--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2008.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2008.zip [following]
# --2024-04-23 00:01:24--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2008.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1481792 (1.4M) [application/zip]
# Saving to: ‘Commoditites2008.zip.1’
#
# Commoditites2008.zi 100%[===================>]   1.41M  --.-KB/s    in 0.04s
#
# 2024-04-23 00:01:24 (32.8 MB/s) - ‘Commoditites2008.zip.1’ saved [1481792/1481792]
#
# --2024-04-23 00:01:24--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2009.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2009.zip [following]
# --2024-04-23 00:01:25--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2009.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1488706 (1.4M) [application/zip]
# Saving to: ‘Commoditites2009.zip.1’
#
# Commoditites2009.zi 100%[===================>]   1.42M  --.-KB/s    in 0.03s
#
# 2024-04-23 00:01:25 (45.3 MB/s) - ‘Commoditites2009.zip.1’ saved [1488706/1488706]
#
# --2024-04-23 00:01:25--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2010.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2010.zip [following]
# --2024-04-23 00:01:25--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2010.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10443676 (10.0M) [application/zip]
# Saving to: ‘Commoditites2010.zip.1’
#
# Commoditites2010.zi 100%[===================>]   9.96M  --.-KB/s    in 0.07s
#
# 2024-04-23 00:01:26 (140 MB/s) - ‘Commoditites2010.zip.1’ saved [10443676/10443676]
#
# --2024-04-23 00:01:26--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2011.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2011.zip [following]
# --2024-04-23 00:01:26--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2011.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10491055 (10M) [application/zip]
# Saving to: ‘Commoditites2011.zip.1’
#
# Commoditites2011.zi 100%[===================>]  10.00M  --.-KB/s    in 0.07s
#
# 2024-04-23 00:01:26 (139 MB/s) - ‘Commoditites2011.zip.1’ saved [10491055/10491055]
#
# --2024-04-23 00:01:26--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2012.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2012.zip [following]
# --2024-04-23 00:01:27--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2012.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10753299 (10M) [application/zip]
# Saving to: ‘Commoditites2012.zip.1’
#
# Commoditites2012.zi 100%[===================>]  10.25M  --.-KB/s    in 0.06s
#
# 2024-04-23 00:01:27 (168 MB/s) - ‘Commoditites2012.zip.1’ saved [10753299/10753299]
#
# --2024-04-23 00:01:27--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2013.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2013.zip [following]
# --2024-04-23 00:01:27--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2013.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10874248 (10M) [application/zip]
# Saving to: ‘Commoditites2013.zip.1’
#
# Commoditites2013.zi 100%[===================>]  10.37M  --.-KB/s    in 0.07s
#
# 2024-04-23 00:01:28 (143 MB/s) - ‘Commoditites2013.zip.1’ saved [10874248/10874248]
#
# --2024-04-23 00:01:28--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2014.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2014.zip [following]
# --2024-04-23 00:01:28--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2014.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10880027 (10M) [application/zip]
# Saving to: ‘Commoditites2014.zip.1’
#
# Commoditites2014.zi 100%[===================>]  10.38M  --.-KB/s    in 0.07s
#
# 2024-04-23 00:01:28 (147 MB/s) - ‘Commoditites2014.zip.1’ saved [10880027/10880027]
#
# --2024-04-23 00:01:28--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2015.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2015.zip [following]
# --2024-04-23 00:01:29--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2015.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11181741 (11M) [application/zip]
# Saving to: ‘Commoditites2015.zip.1’
#
# Commoditites2015.zi 100%[===================>]  10.66M  --.-KB/s    in 0.07s
#
# 2024-04-23 00:01:29 (146 MB/s) - ‘Commoditites2015.zip.1’ saved [11181741/11181741]
#
# --2024-04-23 00:01:29--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2016.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2016.zip [following]
# --2024-04-23 00:01:29--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2016.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11110346 (11M) [application/zip]
# Saving to: ‘Commoditites2016.zip.1’
#
# Commoditites2016.zi 100%[===================>]  10.59M  --.-KB/s    in 0.08s
#
# 2024-04-23 00:01:30 (139 MB/s) - ‘Commoditites2016.zip.1’ saved [11110346/11110346]
#
# --2024-04-23 00:01:30--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2017.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2017.zip [following]
# --2024-04-23 00:01:30--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2017.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12103628 (12M) [application/zip]
# Saving to: ‘Commoditites2017.zip.1’
#
# Commoditites2017.zi 100%[===================>]  11.54M  --.-KB/s    in 0.07s
#
# 2024-04-23 00:01:30 (160 MB/s) - ‘Commoditites2017.zip.1’ saved [12103628/12103628]
#
# --2024-04-23 00:01:30--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2018.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2018.zip [following]
# --2024-04-23 00:01:31--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2018.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11931463 (11M) [application/zip]
# Saving to: ‘Commoditites2018.zip.1’
#
# Commoditites2018.zi 100%[===================>]  11.38M  --.-KB/s    in 0.08s
#
# 2024-04-23 00:01:31 (139 MB/s) - ‘Commoditites2018.zip.1’ saved [11931463/11931463]
#
# --2024-04-23 00:01:31--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2019.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2019.zip [following]
# --2024-04-23 00:01:31--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2019.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11752917 (11M) [application/zip]
# Saving to: ‘Commoditites2019.zip.1’
#
# Commoditites2019.zi 100%[===================>]  11.21M  --.-KB/s    in 0.1s
#
# 2024-04-23 00:01:32 (107 MB/s) - ‘Commoditites2019.zip.1’ saved [11752917/11752917]
#
# --2024-04-23 00:01:32--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2020.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2020.zip [following]
# --2024-04-23 00:01:32--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2020.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11436386 (11M) [application/zip]
# Saving to: ‘Commoditites2020.zip.1’
#
# Commoditites2020.zi 100%[===================>]  10.91M  --.-KB/s    in 0.08s
#
# 2024-04-23 00:01:32 (143 MB/s) - ‘Commoditites2020.zip.1’ saved [11436386/11436386]
#
# --2024-04-23 00:01:32--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2021.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2021.zip [following]
# --2024-04-23 00:01:33--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2021.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11466012 (11M) [application/zip]
# Saving to: ‘Commoditites2021.zip.1’
#
# Commoditites2021.zi 100%[===================>]  10.93M  --.-KB/s    in 0.07s
#
# 2024-04-23 00:01:33 (150 MB/s) - ‘Commoditites2021.zip.1’ saved [11466012/11466012]
#
# --2024-04-23 00:01:33--  https://github.com/edufsi/Projeto-Desafio/raw/Eduardo/Dados/dados_commodities/Commoditites2022.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2022.zip [following]
# --2024-04-23 00:01:33--  https://raw.githubusercontent.com/edufsi/Projeto-Desafio/Eduardo/Dados/dados_commodities/Commoditites2022.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9614335 (9.2M) [application/zip]
# Saving to: ‘Commoditites2022.zip.1’
#
# Commoditites2022.zi 100%[===================>]   9.17M  --.-KB/s    in 0.06s
#
# 2024-04-23 00:01:34 (156 MB/s) - ‘Commoditites2022.zip.1’ saved [9614335/9614335]

# %%
import pandas as pd

# %%
# Função toma um ano inicial e um ano final entre o intervalo aceito (1988, 2022) e retorna um dataframe
# que vai do ano inicial ao final com os dados de importações e exportações de comomdities no mundo

def imp_dados_commodities(ano_inicio, ano_fim):
  if ano_inicio < 1988 or ano_fim > 2022 or ano_inicio > ano_fim:
    raise Exception("Datas para importação dos dados inválidas. O ano mínimo é 1988 e o ano máximo é 2022")

  dados_finais = pd.DataFrame()

  for i in range(ano_inicio, ano_fim + 1):
    dados = pd.read_csv(f'Commoditites{i}.zip', encoding='ISO-8859-1', sep=',', compression='zip')
    dados_finais = pd.concat([dados_finais, dados])

  dados_finais.index = range(len(dados_finais))

  return dados_finais
# Out:
#         Unnamed: 0 Country or Area  Year  \
# 0             4586       Australia  1990
# 1             4587       Australia  1990
# 2             4588       Australia  1990
# 3             4589       Australia  1990
# 4             4590       Australia  1990
# ...            ...             ...   ...
# 496640     7339891          Zambia  2000
# 496641     7339892          Zambia  2000
# 496642     7339952        Zimbabwe  2000
# 496643     7339953        Zimbabwe  2000
# 496644     7339954        Zimbabwe  2000
#
#                                           Commodity       Flow  Trade (USD)  \
# 0                   Horses, live pure-bred breeding     Import   4976357.00
# 1                   Horses, live pure-bred breeding  Re-Export    540574.00
# 2                   Horses, live pure-bred breeding     Export  10798944.00
# 3            Horses, live except pure-bred breeding     Import  76461160.00
# 4            Horses, live except pure-bred breeding  Re-Export   4415400.00
# ...                                             ...        ...          ...
# 496640  Commodities not specified according to kind  Re-Export   2094869.00
# 496641  Commodities not specified according to kind     Export   2381374.00
# 496642  Commodities not specified according to kind     Export  12301845.80
# 496643  Commodities not specified according to kind  Re-Export      5384.35
# 496644  Commodities not specified according to kind     Import  22300081.99
#
#         Weight (kg)        Quantity Name  Quantity
# 0               NaN      Number of items     296.0
# 1            7812.0  Weight in kilograms    7812.0
# 2          298700.0  Weight in kilograms  298700.0
# 3               NaN      Number of items    2553.0
# 4           46687.0  Weight in kilograms   46687.0
# ...             ...                  ...       ...
# 496640          NaN          No Quantity       NaN
# 496641          NaN          No Quantity       NaN
# 496642          NaN          No Quantity       NaN
# 496643          NaN          No Quantity       NaN
# 496644          NaN          No Quantity       NaN
#
# [496645 rows x 9 columns]
